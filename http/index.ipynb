# %%
import requests
# https://ticket.ipvs.cloud
response = requests.post("http://localhost:8000/auth/users/", json={
    "email": "kwas1@gmail.com",
    "password": "macy3663"
}, timeout=10)

# response.raise_for_status()

data = response.json()

print(data)
# Out:
# {'email': 'kwas1@gmail.com', 'id': 4}

# %%
import requests

response = requests.post("http://localhost:8000/auth/jwt/create/", json={
    "email": "kwas1@gmail.com",
    "password": "macy3663"
}, timeout=10)

# response.raise_for_status()

data = response.json()

print(data)
# Out:
# {'refresh': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoicmVmcmVzaCIsImV4cCI6MTc2MzI4Njc0NywiaWF0IjoxNzYzMjAwMzQ3LCJqdGkiOiI0ODMyN2ViNDM2NzQ0ZjgwOGZjMjlhY2NkZWUxZjc2NiIsInVzZXJfaWQiOiI0In0.EGig09z7seSrmNIH0-V69gp6hvKmedVDYoocHViS2VU', 'access': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzYzMjAwNjQ3LCJpYXQiOjE3NjMyMDAzNDcsImp0aSI6IjJiZGU5YjcwNzRhODQyNGRhNDA0ODg5YWMwMGQ4NjhiIiwidXNlcl9pZCI6IjQifQ.dnYcUmDv_cs0iwGOuiltJZa6sMlP9OE3HwTUjr-WhdM'}

# %%
import requests

response = requests.post("http://localhost:8000/auth/jwt/create/", json={
    "email": "kwasa@gmail.com",
    "password": "macy3663"
}, timeout=10)

response.raise_for_status()

data = response.json()

print(data)
# Out:
# {'refresh': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoicmVmcmVzaCIsImV4cCI6MTc2MzE5MTg4OCwiaWF0IjoxNzYzMTA1NDg4LCJqdGkiOiJlMmQ3OTdkN2JmNDI0OTZlYjExYjdiNDY5YTkzZjgyZCIsInVzZXJfaWQiOiIzIn0.R7EGaY4IBxjIlLQpJdGPSmZBihRBV4-D60PmW8wtv90', 'access': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzYzMTA1Nzg4LCJpYXQiOjE3NjMxMDU0ODgsImp0aSI6IjhhYjFhOGQ2NTYwYTQxYWE4NzhhNDAwMzJjNmZkODI4IiwidXNlcl9pZCI6IjMifQ.lrEAbWGFPycFIs3C7Nu5SOXdCCLrkNtx8Vcgt0daOFg'}

# %%
response = requests.get("http://localhost:8000/auth/users/me/", headers={
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzYzMTA1Nzg4LCJpYXQiOjE3NjMxMDU0ODgsImp0aSI6IjhhYjFhOGQ2NTYwYTQxYWE4NzhhNDAwMzJjNmZkODI4IiwidXNlcl9pZCI6IjMifQ.lrEAbWGFPycFIs3C7Nu5SOXdCCLrkNtx8Vcgt0daOFg"
}, timeout=10)

print(response.json())
# Out:
# {'id': 3, 'email': 'kwasa@gmail.com'}
